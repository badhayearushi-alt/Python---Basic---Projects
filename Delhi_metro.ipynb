# %% [markdown]
# <a href="https://colab.research.google.com/github/badhayearushi-alt/Python---Basic---Projects/blob/main/Delhi_metro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (8,5)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3542aec9-7f9a-4b9f-bae1-180ed976d929" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3542aec9-7f9a-4b9f-bae1-180ed976d929">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("DELHI_METRO_DATA.csv")

# %%
df.head()
# Out:
#             Station              Line   Latitude  Longitude
# 0      Adarsh Nagar       Yellow Line  28.714401  77.167288
# 1             AIIMS       Yellow Line  28.566860  77.207806
# 2        Akshardham         Blue Line  28.617842  77.279488
# 3  Anand Vihar ISBT  Blue Line branch  28.646753  77.318004
# 4        Arjan Garh       Yellow Line  28.480735  77.125762

# %%
df.tail()
# Out:
#               Station         Line   Latitude  Longitude
# 223      Vidhan Sabha  Yellow Line  28.686322  77.221727
# 224        Vinobapuri    Pink Line  28.566976  77.249191
# 225  Vishwa Vidyalaya  Yellow Line  28.695037  77.214719
# 226           Welcome     Red Line  28.651718  77.221939
# 227       Yamuna Bank    Blue Line  28.623278  77.267924

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (228, 4)

# %%
print(df.columns)
# Out:
# Index(['Station', 'Line', 'Latitude', 'Longitude'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Station       object
# Line          object
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Station      0
# Line         0
# Latitude     7
# Longitude    7
# dtype: int64

# %%
df.describe(include="all")
# Out:
#              Station       Line    Latitude   Longitude
# count            228        228  221.000000  221.000000
# unique           228         11         NaN         NaN
# top     Adarsh Nagar  Blue Line         NaN         NaN
# freq               1         49         NaN         NaN
# mean             NaN        NaN   28.560811   77.183246
# std              NaN        NaN    0.723198    0.101508
# min              NaN        NaN   17.920862   76.870085
# 25%              NaN        NaN   28.558581   77.107181
# 50%              NaN        NaN   28.622288   77.199336
# 75%              NaN        NaN   28.668945   77.260667
# max              NaN        NaN   28.878965   77.528502

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Station    228 non-null    object
#  1   Line       228 non-null    object
#  2   Latitude   221 non-null    float64
#  3   Longitude  221 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 7.3+ KB

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df = df.drop_duplicates()
print(df.shape)
# Out:
# (228, 4)

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

df[numeric_cols].hist(figsize=(12,8))
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[numeric_cols])
plt.xticks(rotation=45)
plt.show()

# %%
 plt.figure(figsize=(10,6))
 sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm")
 plt.show()

# %%
cat_cols = df.select_dtypes(include="object").columns

if len(cat_cols) > 0:
    df[cat_cols[0]].value_counts().plot(kind="bar")
    plt.xticks(rotation=45)
    plt.title(cat_cols[0])
    plt.show()

# %%
if len(cat_cols) > 0:
    df[cat_cols[0]].value_counts().head(5).plot(
        kind="pie",
        autopct="%1.1f%%"
    )
    plt.ylabel("")
    plt.show()

# %%
if len(numeric_cols) >= 2:
    plt.scatter(df[numeric_cols[0]], df[numeric_cols[1]])
    plt.xlabel(numeric_cols[0])
    plt.ylabel(numeric_cols[1])
    plt.show()

# %%
print("Dataset Name: Delhi Metro Data")
print("Rows and Columns:", df.shape)
print("Number of Features:", len(df.columns))
print("Columns:")
print(df.columns.tolist())

print("\nSummary:")
print("- Dataset loaded successfully.")
print("- Missing values checked.")
print("- Duplicate rows removed.")
print("- Visualizations created successfully.")
# Out:
# Dataset Name: Delhi Metro Data
# Rows and Columns: (228, 4)
# Number of Features: 4
# Columns:
# ['Station', 'Line', 'Latitude', 'Longitude']
#
# Summary:
# - Dataset loaded successfully.
# - Missing values checked.
# - Duplicate rows removed.
# - Visualizations created successfully.
