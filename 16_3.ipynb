# %% [markdown]
# <a href="https://colab.research.google.com/github/badhayearushi-alt/Python---Basic---Projects/blob/main/16_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c1fd4fb0-6e78-4f80-a691-a4b0882df1e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1fd4fb0-6e78-4f80-a691-a4b0882df1e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("fifa.csv")
df.head()
# Out:
#               Player  Age Nationality             Club Position  Overall  \
# 0       Lionel Messi   36   Argentina      Inter Miami       RW       90
# 1  Cristiano Ronaldo   39    Portugal         Al Nassr       ST       89
# 2      Kylian Mbappe   26      France      Real Madrid       ST       91
# 3     Erling Haaland   25      Norway  Manchester City       ST       91
# 4    Kevin De Bruyne   34     Belgium  Manchester City       CM       90
#
#    Potential      Value Preferred_Foot
# 0         90   41000000           Left
# 1         89   15000000          Right
# 2         95  180000000          Right
# 3         94  170000000           Left
# 4         90   60000000          Right

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player          10 non-null     object
#  1   Age             10 non-null     int64
#  2   Nationality     10 non-null     object
#  3   Club            10 non-null     object
#  4   Position        10 non-null     object
#  5   Overall         10 non-null     int64
#  6   Potential       10 non-null     int64
#  7   Value           10 non-null     int64
#  8   Preferred_Foot  10 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 852.0+ bytes
#              Age    Overall  Potential         Value
# count  10.000000  10.000000   10.00000  1.000000e+01
# mean   31.000000  89.900000   91.40000  9.710000e+07
# std     5.477226   0.994429    2.75681  6.995784e+07
# min    23.000000  88.000000   88.00000  1.500000e+07
# 25%    26.000000  89.250000   89.25000  3.650000e+07
# ...

# %%
df.isnull().sum()
# Out:
# Player            0
# Age               0
# Nationality       0
# Club              0
# Position          0
# Overall           0
# Potential         0
# Value             0
# Preferred_Foot    0
# dtype: int64

# %%
print("Numerical Columns")
for col in df.columns:
    if df[col].dtype != "object":
            print(col)

            print("\nCategorical Columns")
            for col in df.columns:
                if df[col].dtype == "object":
                        print(col)
# Out:
# Numerical Columns
# Age
#
# Categorical Columns
# Player
# Nationality
# Club
# Position
# Preferred_Foot
# Overall
#
# Categorical Columns
# Player
# Nationality
# Club
# Position
# Preferred_Foot
# Potential
#
# Categorical Columns
# Player
# Nationality
# Club
# Position
# Preferred_Foot
# Value
#
# Categorical Columns
# Player
# Nationality
# Club
# Position
# Preferred_Foot

# %%
df[["Age","Overall","Potential","Value"]].hist(figsize=(10,8))
plt.show()

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.countplot(x="Preferred_Foot", data=df)
plt.title("Preferred Foot")

plt.subplot(1,2,2)
sns.countplot(x="Position", data=df)
plt.title("Position")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="Preferred_Foot", y="Overall", data=df)
plt.title("Overall Rating by Preferred Foot")
plt.show()
