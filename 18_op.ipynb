# %% [markdown]
# <a href="https://colab.research.google.com/github/badhayearushi-alt/Python---Basic---Projects/blob/main/18_op.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-430abfed-10e0-46cb-b8e3-0bf2677df75a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-430abfed-10e0-46cb-b8e3-0bf2677df75a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("insurance.csv")

# %%
# 3. Display First Five Records
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# 4. Dataset Shape
print(df.shape)
# Out:
# (1338, 7)

# %%
# 5. Column Names
print(df.columns)
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
 # 6. Dataset Information
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# 7. Missing Values
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
# 8. Summary Statistics
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
 # 9. Numerical Columns
 print(df.select_dtypes(include=np.number).columns)
# Out:
# Index(['age', 'bmi', 'children', 'expenses'], dtype='object')

# %%
# 10. Categorical Columns
print(df.select_dtypes(include="object").columns)
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
# 11. Histogram (Subplots)
df.hist(figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
# 12. Count Plot
sns.countplot(x=df["smoker"])
plt.xticks(rotation=45)
plt.show()

# %%
# 13. Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.boxplot(y=df["expenses"])
plt.show()

# %%
# 15. Scatter Plot
plt.figure(figsize=(8,5))
plt.scatter(df["age"], df["expenses"])
plt.xlabel("Age")
plt.ylabel("Expenses")
plt.show()

# %%
# 16. One-Hot Encoding
df_encoded = pd.get_dummies(df, drop_first=True)
df_encoded.head()
# Out:
#    age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0  16884.92     False        True             False
# 1   18  33.8         1   1725.55      True       False             False
# 2   28  33.0         3   4449.46      True       False             False
# 3   33  22.7         0  21984.47      True       False              True
# 4   32  28.9         0   3866.86      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %%
# 17. Feature Scaling
scaler = StandardScaler()
num_cols = df.select_dtypes(include=np.number).columns
df[num_cols] = scaler.fit_transform(df[num_cols])
df.head()
# Out:
#         age     sex       bmi  children smoker     region  expenses
# 0 -1.438764  female -0.453646 -0.908614    yes  southwest  0.298583
# 1 -1.509965    male  0.514186 -0.078767     no  southeast -0.953689
# 2 -0.797954    male  0.382954  1.580926     no  southeast -0.728675
# 3 -0.441948    male -1.306650 -0.908614     no  northwest  0.719843
# 4 -0.513149    male -0.289606 -0.908614     no  northwest -0.776802

# %%
 # 1. Import Libraries
 import pandas as pd
 import numpy as np
 import matplotlib.pyplot as plt
 import seaborn as sns

 from sklearn.preprocessing import StandardScaler

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90b3cb40-b422-4ecf-88ba-a728e5802256" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90b3cb40-b422-4ecf-88ba-a728e5802256">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("fifa.csv")

# %%
# 3. Display First Five Records
df.head()
# Out:
#               Player  Age Nationality             Club Position  Overall  \
# 0       Lionel Messi   36   Argentina      Inter Miami       RW       90
# 1  Cristiano Ronaldo   39    Portugal         Al Nassr       ST       89
# 2      Kylian Mbappe   26      France      Real Madrid       ST       91
# 3     Erling Haaland   25      Norway  Manchester City       ST       91
# 4    Kevin De Bruyne   34     Belgium  Manchester City       CM       90
#
#    Potential      Value Preferred_Foot
# 0         90   41000000           Left
# 1         89   15000000          Right
# 2         95  180000000          Right
# 3         94  170000000           Left
# 4         90   60000000          Right

# %%
# 4. Dataset Shape
print(df.shape)
# Out:
# (10, 9)

# %%
# 5. Column Names
print(df.columns)
# Out:
# Index(['Player', 'Age', 'Nationality', 'Club', 'Position', 'Overall',
#        'Potential', 'Value', 'Preferred_Foot'],
#       dtype='object')

# %%
# 6. Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player          10 non-null     object
#  1   Age             10 non-null     int64
#  2   Nationality     10 non-null     object
#  3   Club            10 non-null     object
#  4   Position        10 non-null     object
#  5   Overall         10 non-null     int64
#  6   Potential       10 non-null     int64
#  7   Value           10 non-null     int64
#  8   Preferred_Foot  10 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 852.0+ bytes

# %%
# 7. Missing Values
print(df.isnull().sum())
# Out:
# Player            0
# Age               0
# Nationality       0
# Club              0
# Position          0
# Overall           0
# Potential         0
# Value             0
# Preferred_Foot    0
# dtype: int64

# %%
# 8. Summary Statistics
df.describe()
# Out:
#              Age    Overall  Potential         Value
# count  10.000000  10.000000   10.00000  1.000000e+01
# mean   31.000000  89.900000   91.40000  9.710000e+07
# std     5.477226   0.994429    2.75681  6.995784e+07
# min    23.000000  88.000000   88.00000  1.500000e+07
# 25%    26.000000  89.250000   89.25000  3.650000e+07
# 50%    33.500000  90.000000   90.00000  7.500000e+07
# 75%    34.000000  90.750000   94.00000  1.700000e+08
# max    39.000000  91.000000   95.00000  1.800000e+08

# %%
# 9. Numerical Columns
print(df.select_dtypes(include=np.number).columns)
# Out:
# Index(['Age', 'Overall', 'Potential', 'Value'], dtype='object')

# %%
# 10. Categorical Columns
print(df.select_dtypes(include="object").columns)
# Out:
# Index(['Player', 'Nationality', 'Club', 'Position', 'Preferred_Foot'], dtype='object')

# %%
# 11. Histogram (Subplots)
df.hist(figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
# 12. Count Plot
sns.countplot(x=df["Preferred_Foot"])
plt.xticks(rotation=45)
plt.show()

# %%
# 13. Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
# 14. Box Plot
sns.boxplot(y=df["Value"])
plt.show()

# %%
# 15. Scatter Plot
plt.figure(figsize=(8,5))
plt.scatter(df["Age"], df["Value"])
plt.xlabel("Age")
plt.ylabel("Value")
plt.show()

# %%
# 16. One-Hot Encoding
df_encoded = pd.get_dummies(df, drop_first=True)
df_encoded.head()
# Out:
#    Age  Overall  Potential      Value  Player_Erling Haaland  \
# 0   36       90         90   41000000                  False
# 1   39       89         89   15000000                  False
# 2   26       91         95  180000000                  False
# 3   25       91         94  170000000                   True
# 4   34       90         90   60000000                  False
#
#    Player_Harry Kane  Player_Jude Bellingham  Player_Kevin De Bruyne  \
# 0              False                   False                   False
# 1              False                   False                   False
# 2              False                   False                   False
# 3              False                   False                   False
# 4              False                   False                    True
#
#    Player_Kylian Mbappe  Player_Lionel Messi  ...  Club_Inter Miami  \
# 0                 False                 True  ...              True
# ...

# %%
# 17. Feature Scaling
scaler = StandardScaler()
num_cols = df.select_dtypes(include=np.number).columns
df[num_cols] = scaler.fit_transform(df[num_cols])
df.head()
# Out:
#               Player       Age Nationality             Club Position  \
# 0       Lionel Messi  0.962250   Argentina      Inter Miami       RW
# 1  Cristiano Ronaldo  1.539601    Portugal         Al Nassr       ST
# 2      Kylian Mbappe -0.962250      France      Real Madrid       ST
# 3     Erling Haaland -1.154701      Norway  Manchester City       ST
# 4    Kevin De Bruyne  0.577350     Belgium  Manchester City       CM
#
#     Overall  Potential     Value Preferred_Foot
# 0  0.106000  -0.535303 -0.845289           Left
# 1 -0.953998  -0.917663 -1.237045          Right
# 2  1.165998   1.376494  1.249099          Right
# 3  1.165998   0.994135  1.098424           Left
# 4  0.106000  -0.535303 -0.559006          Right
